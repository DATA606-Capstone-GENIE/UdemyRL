# %% [markdown]
# <div style="text-align:center">
#     <h1>
#         Deep SARSA
#     </h1>
# </div>
#
# <br><br>
#
# <div style="text-align:center">
#
# In this notebook, we extend the SARSA algorithm to use function approximators (Neural Networks). The resulting algorithm is known as Deep SARSA.
# </div>
#
# <br><br>
# <div style="text-align:center">
#     <b>This notebook belongs to section 8 of the course "Reinforcement Learning: beginner to master".</b>
#     <br><br>
#     <a href="https://www.udemy.com">Reinforcement Learning: beginner to master</a> (English)
#     <br>
#     <a href="https://www.udemy.com">Reinforcement Learning: de principiante a maestro</a> (Spanish)
# </div>
#
# <br>
#
# <table style="width:35%">
#   <tr style="background-color: transparent">
#     <td style="width: 45%">
#         <a target="_parent" href="https://www.evlabs.io" style="float: center">
#             <img src="img/evlabs-square.png" width="75"/>
#         </a>
#     </td>
#     <td valign="bottom">
#         <a target="_parent" href="https://www.youtube.com/channel/UCksRNSzWuMV5IfdrPlglqqw">
#             <img src="img/YouTube.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://www.linkedin.com/company/evlabs">
#             <img src="img/LinkedIn.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://twitter.com/evelabs">
#             <img src="img/Twitter.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://github.com/escape-velocity-labs/">
#             <img src="img/GitHub.png" width="35"/>
#         </a>
#     </td>
#
#   </tr>
#   <tr style="background-color: transparent">
#     <th style="text-align: center; width: 70%">Escape Velocity Labs</th>
#   </tr>
#
# </table>
#
# <br>

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import random
import copy
import gym
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch import nn as nn
from torch.optim import AdamW # more effective than SGD
from tqdm import tqdm


from utils import plot_cost_to_go, plot_max_q, test_agent, plot_stats, seed_everything

# %matplotlib notebook
# Out:
# /opt/anaconda3/envs/bmrl/lib/python3.8/site-packages/numexpr/expressions.py:21: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_forbids_neg_powint = LooseVersion(numpy.__version__) >= LooseVersion('1.12.0b1')

# %% [markdown]
# ## Create and prepare the environment

# %% [markdown]
# ### Create the environment

# %%
env = gym.make("MountainCar-v0")
seed_everything(env)
# Out:
# /opt/anaconda3/envs/bmrl/lib/python3.8/site-packages/gym/core.py:172: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed) instead.
#   deprecation(

# %%
state_dims = env.observation_space.shape[0]
num_actions = env.action_space.n
print(f"MountainCar env: State dimensions: {state_dims}, Number of actions:{num_actions}")
# Out:
# MountainCar env: State dimensions: 2, Number of actions:3

# %% [markdown]
# ### Prepare the environment to work with PyTorch

# %% [markdown]
# class PreprocessEnv(gym.Wrapper):
#
#     def __init__(self,env):
#         gym.Wrapper.__init__(self,env)
#
#
#     # Wraps env.reset
#     """From the original environment"""
#     def reset(self):
#         state = self.env.reset()
#
#         #  [[0. 0.], [1., 1.]] (N * D) N->Number of observations in that batch; D-> number of dimentions
#         """ But since we want to work with batches, we want to give it extra dimentions. So these observations incorporated into batch."""
#         return torch.from_numpy(state).unsqueeze(dim=0).float()
#
#
#
#     # Wraps env.step
#     def step(self, actoin):
#         actoin = action.item()
#         next_state, reward, done, info = self.env.step(action)
#         next_state = torch.from_numpy(next_state).unsqueeze(dim=0).float()
#         reward = torch.tensor(reward).view(1,-1).float() # [[0.]] tensor of one element, -1 gives one extra dimention.
#         done = torch.tensor(done).view(1,-1)
#         return next_state, reward, done, info

# %%
class PreprocessEnv(gym.Wrapper):
    
    def __init__(self,env):
        gym.Wrapper.__init__(self,env)
        
        
    # Wraps env.reset
    def reset(self):
        state = self.env.reset()
        return torch.from_numpy(state).unsqueeze(dim=0).float()
        
        
    
    # Wraps env.step
    def step(self, actoin):
        actoin_item = action.item()
        next_state, reward, done, info = self.env.step(actoin_item)
        next_state = torch.from_numpy(next_state).unsqueeze(dim=0).float()        
        reward = torch.tensor(reward).view(1,-1).float() # [[0.]] tensor of one element, -1 gives one extra dimention.
        done = torch.tensor(done).view(1,-1)
        return next_state, reward, done, info

# %%
env = PreprocessEnv(env)

# %%
state = env.reset()
action = torch.tensor(0)
next_state, reward, done, info = env.step(action)

print(f"Sample state: {state}")
print(f"Next State: {next_state}, Reward: {reward}, Done: {done}")
# Out:
# Sample state: tensor([[-0.4452,  0.0000]])
# Next State: tensor([[-0.4468, -0.0016]]), Reward: tensor([[-1.]]), Done: tensor([[False]])

# %% [markdown]
# ## Create the Q-Network and policy
#
# <br><br>

# %% [markdown]
# ![Screenshot%202021-03-11%20at%2020.23.56.png](attachment:Screenshot%202021-03-11%20at%2020.23.56.png)

# %% [markdown]
# ### Create the Q-Network: $\hat q(s,a| \theta)$

# %%
q_network = nn.Sequential(
     # nn.Linear  state * W + b
    nn.Linear(state_dims, 128), # 128 defines the first hidden layer size
    #nn.ReLU max(0, state * W + b)
    nn.ReLU(),
    # nn.Linear  state * W + b
    nn.Linear(128, 64), # 128 defines the second hidden layer size
    #nn.ReLU max(0, state * W + b)
    nn.ReLU(),
    nn.Linear(64,num_actions)
)

# %% [markdown]
# ### Create the target Q-Network: $\hat q(s, a|\theta_{targ})$

# %%
target_q_network = copy.deepcopy(q_network)
target_q_network = target_q_network.eval()

# %%
target_q_network
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=3, bias=True)
# )

# %% [markdown]
# ### Create the $\epsilon$-greedy policy: $\pi(s)$

# %%
def policy(state, epsilon=0.):    
    if torch.rand(1) < epsilon:
        return torch.randint(num_actions, (1, 1))
    else:
        av = q_network(state).detach()
        return torch.argmax(av, dim=-1, keepdim=True)

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
plot_cost_to_go(env, q_network, xlabel="Car Position", ylabel="Velocity")

# %% [markdown]
# ## Create the Experience Replay buffer
#
# <br>
# <div style="text-align:center">
#     <p>A simple buffer that stores transitions of arbitrary values, adapted from
#     <a href="https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html#training">this source.</a></p>
# </div>
#
# ![Screenshot%202021-03-11%20at%2020.38.28.png](attachment:Screenshot%202021-03-11%20at%2020.38.28.png)

# %%
class ReplayMemory:
    
    def __init__(self,capacity = 1000000):
        self.capacity = capacity
        self.memory = []
        self.position = 0
    
    # insert. [s, a, r, s']
    def insert(self,transition):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
            
        self.memory[self.position] = transition
        self.position = (self.position + 1) % self.capacity
    
    # sample [[s,a,r,s'],[s,a,r,s']]
    
    def sample(self, batch_size):
        assert self.can_sample(batch_size)
        
        batch = random.sample(self.memory, batch_size)
        
        # [[s, a, r, s'],[s, a, r, s']] -> [[s, s, s, s],[a, a, a, a],[r, r, r, r],[s', s', s', s']]
        batch = zip(*batch)
        return [torch.cat(items) for items in batch] # N * D; N->number of states; D-> Number of dimentions
        
    
    
    # Can_cample -> True/ False :: True, if enough trnsation to begin drawing batches from it. else False.
    def can_sample(self, batch_size):
        return len(self.memory) >= batch_size * 10
        
    
    # __len__
    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ## Implement the algorithm
#
# </br></br>

# %% [markdown]
# ![Screenshot%202021-03-11%20at%2019.03.36.png](attachment:Screenshot%202021-03-11%20at%2019.03.36.png)

# %%
def deep_sarsa(q_network, policy, episodes, alpha=0.001, batch_size=32, gamma = 0.99, epsilon = 0.05):
    optim = AdamW(q_network.parameters(), lr=alpha)
    memory = ReplayMemory(capacity = 1000000)
    stats = {"MSE_Loss":[], "Returns":[]}
    
    for episode in tqdm(range(1,episodes +1)):
        state = env.reset()
        done = False
        ep_return = 0.
        
        while not done:
            action = policy(state, epsilon)
            next_state, reward, done, _ = env.step(action)
            memory.insert([state,action,reward,done,next_state])
            
            if memory.can_sample(batch_size):
                state_b, action_b, reward_b, done_b, next_state_b = memory.sample(batch_size)
                qsa_b = q_network(state_b).gather(1, action_b)
                next_action_b = policy(next_state_b, epsilon)
                next_qsa_b = target_q_network(next_state_b).gather(1,next_action_b)
                target_b = reward_b + ~done_b * gamma * next_qsa_b
                
                loss = F.mse_loss(qsa_b, target_b)
                q_network.zero_grad()
                loss.backward()
                optim.step()
                
                stats["MSE_Loss"].append(loss.item())
            
            state = next_state
            ep_return += reward.item()
            
        stats["Returns"].append(ep_return)
            
        if episode %10 == 0:
            target_q_network.load_state_dict(q_network.state_dict())
            
            
    return stats

# %%
stats = deep_sarsa(q_network, policy, 1500, epsilon=0.01)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [07:34<00:00,  3.30it/s]

# %%
stats
# Out:
# {'MSE_Loss': [0.2609158456325531,
#   0.05981798470020294,
#   91.7584228515625,
#   0.09216499328613281,
#   0.08754361420869827,
#   0.16706202924251556,
#   0.23798735439777374,
#   0.3456513285636902,
#   0.3399449288845062,
#   0.3190901577472687,
#   0.2330646514892578,
#   0.15074141323566437,
#   0.10349909216165543,
#   0.04740224778652191,
#   0.08863447606563568,
#   0.07980451732873917,
#   0.15084773302078247,
#   0.17870517075061798,
#   0.13274502754211426,
#   0.09825580567121506,
#   0.08919933438301086,
#   0.05983632057905197,
#   0.09650722146034241,
#   0.24932929873466492,
#   0.26136162877082825,
#   0.13914602994918823,
#   91.12579345703125,
#   90.77702331542969,
#   90.0324935913086,
#   0.24185457825660706,
#   0.4778965413570404,
#   0.7574700117111206,
#   0.6817588806152344,
#   87.94960021972656,
#   1.011022686958313,
#   0.7509615421295166,
#   1.0584721565246582,
#   0.6097621321678162,
#   0.5071616172790527,
#   0.4384474456310272,
# ...

# %% [markdown]
# ## Show results

# %% [markdown]
# ### Plot execution stats

# %%
plot_stats(stats)

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
plot_cost_to_go(env, q_network, xlabel="Car Position", ylabel="Velocity of the car")

# %% [markdown]
# ### Show resulting policy: $\pi(s)$

# %%
plot_max_q(env, q_network, xlabel= "Car Position", ylabel="Velocity", action_labels = ["Back", "Do nothing","Forward"])

# %% [markdown]
# ### Test the resulting agent

# %%
# %matplotlib inline
test_agent(env, policy, episodes=2)

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Deep Reinforcement Learning with Experience Replay Based on SARSA](https://www.researchgate.net/publication/313803199_Deep_reinforcement_learning_with_experience_replay_based_on_SARSA)
